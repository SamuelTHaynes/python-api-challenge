# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 609

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through cities
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=imperial"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | college
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | hawaiian paradise park
# Processing Record 6 of Set 1 | papatowai
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | taybad
# Processing Record 9 of Set 1 | grytviken
# Processing Record 10 of Set 1 | kulhudhuffushi
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | ciudad lazaro cardenas
# Processing Record 14 of Set 1 | crane
# Processing Record 15 of Set 1 | edinburgh of the seven seas
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 18 of Set 1 | kapuskasing
# Processing Record 19 of Set 1 | saipan
# Processing Record 20 of Set 1 | calvinia
# Processing Record 21 of Set 1 | mangualde
# Processing Record 22 of Set 1 | alice springs
# Processing Record 23 of Set 1 | blackmans bay
# Processing Record 24 of Set 1 | laguna
# Processing Record 25 of Set 1 | kermanshah
# Processing Record 26 of Set 1 | fale old settlement
# Processing Record 27 of Set 1 | jerez de garcia salinas
# Processing Record 28 of Set 1 | montrose
# Processing Record 29 of Set 1 | myshkin
# Processing Record 30 of Set 1 | al jawf
# Processing Record 31 of Set 1 | vorgashor
# Processing Record 32 of Set 1 | stanley
# Processing Record 33 of Set 1 | thinadhoo
# Processing Record 34 of Set 1 | loen
# Processing Record 35 of Set 1 | puerto natales
# Processing Record 36 of Set 1 | st. john's
# Processing Record 37 of Set 1 | novyy urengoy
# Processing Record 38 of Set 1 | chonchi
# Processing Record 39 of Set 1 | verkhov'ye
# Processing Record 40 of Set 1 | khilok
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | aguada de pasajeros
# Processing Record 43 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 44 of Set 1 | hamilton
# Processing Record 45 of Set 1 | newman
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | ola
# Processing Record 48 of Set 1 | qaqortoq
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | olonkinbyen
# Processing Record 0 of Set 2 | vadso
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | ust-nera
# Processing Record 3 of Set 2 | taveta
# Processing Record 4 of Set 2 | umm qasr
# Processing Record 5 of Set 2 | point pedro
# Processing Record 6 of Set 2 | ta`u
# Processing Record 7 of Set 2 | nkurenkuru
# City not found. Skipping...
# Processing Record 8 of Set 2 | vilyuchinsk
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | port mathurin
# Processing Record 11 of Set 2 | wajir
# Processing Record 12 of Set 2 | invercargill
# Processing Record 13 of Set 2 | lihue
# Processing Record 14 of Set 2 | lompoc
# Processing Record 15 of Set 2 | kalianget
# Processing Record 16 of Set 2 | tiksi
# Processing Record 17 of Set 2 | nova sintra
# Processing Record 18 of Set 2 | tolanaro
# Processing Record 19 of Set 2 | midvagur
# Processing Record 20 of Set 2 | atafu village
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | bayganin
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | fort mcmurray
# Processing Record 25 of Set 2 | san antonio de pale
# Processing Record 26 of Set 2 | cururupu
# Processing Record 27 of Set 2 | sisimiut
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | kisoro
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | isangel
# Processing Record 33 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 2 | klyuchi
# Processing Record 35 of Set 2 | arno
# Processing Record 36 of Set 2 | zalesovo
# Processing Record 37 of Set 2 | nanao
# Processing Record 38 of Set 2 | bilibino
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 41 of Set 2 | hobyo
# Processing Record 42 of Set 2 | tazovsky
# Processing Record 43 of Set 2 | mount isa
# Processing Record 44 of Set 2 | kirakira
# Processing Record 45 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 2 | ayaviri
# Processing Record 47 of Set 2 | copala
# Processing Record 48 of Set 2 | bogorodsk
# Processing Record 49 of Set 2 | belyy yar
# Processing Record 0 of Set 3 | port elizabeth
# Processing Record 1 of Set 3 | isafjordur
# Processing Record 2 of Set 3 | manga
# Processing Record 3 of Set 3 | arteche
# Processing Record 4 of Set 3 | colonia
# Processing Record 5 of Set 3 | susuman
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | lata
# Processing Record 8 of Set 3 | taesal-li
# Processing Record 9 of Set 3 | tsiombe
# Processing Record 10 of Set 3 | enewetak
# Processing Record 11 of Set 3 | badger
# Processing Record 12 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 13 of Set 3 | botshabelo
# Processing Record 14 of Set 3 | zonguldak
# Processing Record 15 of Set 3 | tegueste
# Processing Record 16 of Set 3 | suva
# Processing Record 17 of Set 3 | beau vallon
# Processing Record 18 of Set 3 | selkirk
# Processing Record 19 of Set 3 | mil'kovo
# Processing Record 20 of Set 3 | hithadhoo
# Processing Record 21 of Set 3 | san patricio
# Processing Record 22 of Set 3 | margaret river
# Processing Record 23 of Set 3 | iqaluit
# Processing Record 24 of Set 3 | san fernando
# Processing Record 25 of Set 3 | meadow lake
# Processing Record 26 of Set 3 | anadyr
# Processing Record 27 of Set 3 | birao
# Processing Record 28 of Set 3 | beyneu
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | jamestown
# Processing Record 31 of Set 3 | mount gambier
# Processing Record 32 of Set 3 | anna regina
# Processing Record 33 of Set 3 | sterling
# Processing Record 34 of Set 3 | masterton
# Processing Record 35 of Set 3 | general pinedo
# Processing Record 36 of Set 3 | tofol
# Processing Record 37 of Set 3 | ghat
# Processing Record 38 of Set 3 | teshi old town
# Processing Record 39 of Set 3 | saudarkrokur
# Processing Record 40 of Set 3 | yuci
# Processing Record 41 of Set 3 | tralee
# Processing Record 42 of Set 3 | la ronge
# Processing Record 43 of Set 3 | sao vicente
# Processing Record 44 of Set 3 | guanare
# Processing Record 45 of Set 3 | austin
# Processing Record 46 of Set 3 | san pedro pochutla
# Processing Record 47 of Set 3 | severo-yeniseyskiy
# Processing Record 48 of Set 3 | cooma
# Processing Record 49 of Set 3 | mangai
# Processing Record 0 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 1 of Set 4 | akrehamn
# Processing Record 2 of Set 4 | valparaiso
# Processing Record 3 of Set 4 | tazacorte
# Processing Record 4 of Set 4 | smithers
# Processing Record 5 of Set 4 | manta
# Processing Record 6 of Set 4 | novocherkassk
# Processing Record 7 of Set 4 | qamdo
# Processing Record 8 of Set 4 | longyearbyen
# Processing Record 9 of Set 4 | san jose del guaviare
# Processing Record 10 of Set 4 | santa maria del oro
# Processing Record 11 of Set 4 | boguchany
# Processing Record 12 of Set 4 | kalmunai
# Processing Record 13 of Set 4 | vilyuysk
# Processing Record 14 of Set 4 | san mateo del mar
# Processing Record 15 of Set 4 | quellon
# Processing Record 16 of Set 4 | tobol'sk
# Processing Record 17 of Set 4 | bac lieu
# Processing Record 18 of Set 4 | arar
# Processing Record 19 of Set 4 | kirensk
# Processing Record 20 of Set 4 | queenstown
# Processing Record 21 of Set 4 | gornopravdinsk
# Processing Record 22 of Set 4 | bonthe
# Processing Record 23 of Set 4 | ascension
# Processing Record 24 of Set 4 | utrik
# Processing Record 25 of Set 4 | dakhla
# Processing Record 26 of Set 4 | nogliki
# Processing Record 27 of Set 4 | aasiaat
# Processing Record 28 of Set 4 | trinidad
# Processing Record 29 of Set 4 | ponnampet
# Processing Record 30 of Set 4 | tura
# Processing Record 31 of Set 4 | mont-dore
# Processing Record 32 of Set 4 | wailua homesteads
# Processing Record 33 of Set 4 | lewistown
# Processing Record 34 of Set 4 | bechar
# Processing Record 35 of Set 4 | novodvinsk
# Processing Record 36 of Set 4 | west busselton
# City not found. Skipping...
# Processing Record 37 of Set 4 | dunedin
# Processing Record 38 of Set 4 | cabo san lucas
# Processing Record 39 of Set 4 | tarko-sale
# Processing Record 40 of Set 4 | kudahuvadhoo
# Processing Record 41 of Set 4 | abadeh
# Processing Record 42 of Set 4 | zhezqazghan
# Processing Record 43 of Set 4 | farah
# Processing Record 44 of Set 4 | nuuk
# Processing Record 45 of Set 4 | daulatpur
# Processing Record 46 of Set 4 | biltine
# Processing Record 47 of Set 4 | sinjai
# Processing Record 48 of Set 4 | oranjemund
# Processing Record 49 of Set 4 | sao jose da coroa grande
# Processing Record 0 of Set 5 | whitehorse
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | soe
# Processing Record 3 of Set 5 | mankono
# Processing Record 4 of Set 5 | eforie sud
# Processing Record 5 of Set 5 | enriquillo
# Processing Record 6 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 7 of Set 5 | kotel'nikovo
# Processing Record 8 of Set 5 | ha giang
# Processing Record 9 of Set 5 | polyarnyy
# Processing Record 10 of Set 5 | labasa
# Processing Record 11 of Set 5 | west island
# Processing Record 12 of Set 5 | lae
# Processing Record 13 of Set 5 | turpan
# Processing Record 14 of Set 5 | aras-asan
# Processing Record 15 of Set 5 | juneau
# Processing Record 16 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 17 of Set 5 | beloyarskiy
# Processing Record 18 of Set 5 | carutapera
# Processing Record 19 of Set 5 | prince rupert
# Processing Record 20 of Set 5 | collie
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | bairnsdale
# Processing Record 23 of Set 5 | caleta de carquin
# Processing Record 24 of Set 5 | olvera
# Processing Record 25 of Set 5 | labrador city
# Processing Record 26 of Set 5 | ushuaia
# Processing Record 27 of Set 5 | haiku-pauwela
# Processing Record 28 of Set 5 | mukalla
# Processing Record 29 of Set 5 | ilulissat
# Processing Record 30 of Set 5 | coquimbo
# Processing Record 31 of Set 5 | gurupa
# Processing Record 32 of Set 5 | hailar
# Processing Record 33 of Set 5 | lebu
# Processing Record 34 of Set 5 | kayangel
# Processing Record 35 of Set 5 | astara
# Processing Record 36 of Set 5 | quartu sant'elena
# Processing Record 37 of Set 5 | cockburn town
# Processing Record 38 of Set 5 | waiuku
# Processing Record 39 of Set 5 | port saint john's
# Processing Record 40 of Set 5 | olinda
# Processing Record 41 of Set 5 | nishinoomote
# Processing Record 42 of Set 5 | kashgar
# Processing Record 43 of Set 5 | ambon
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | flying fish cove
# Processing Record 46 of Set 5 | sao gabriel da cachoeira
# Processing Record 47 of Set 5 | greenville
# Processing Record 48 of Set 5 | namtsy
# Processing Record 49 of Set 5 | jaisalmer
# Processing Record 0 of Set 6 | iskateley
# Processing Record 1 of Set 6 | bath
# Processing Record 2 of Set 6 | bubaque
# Processing Record 3 of Set 6 | sandnessjoen
# Processing Record 4 of Set 6 | astaneh-ye ashrafiyeh
# Processing Record 5 of Set 6 | wamba
# Processing Record 6 of Set 6 | shalkar
# Processing Record 7 of Set 6 | embi
# Processing Record 8 of Set 6 | kununurra
# Processing Record 9 of Set 6 | gadzhiyevo
# Processing Record 10 of Set 6 | dudinka
# Processing Record 11 of Set 6 | nouadhibou
# Processing Record 12 of Set 6 | yarmouth
# Processing Record 13 of Set 6 | tefe
# Processing Record 14 of Set 6 | ayer hangat
# City not found. Skipping...
# Processing Record 15 of Set 6 | nizhnyaya tavda
# Processing Record 16 of Set 6 | nago
# Processing Record 17 of Set 6 | inhambane
# Processing Record 18 of Set 6 | island harbour
# Processing Record 19 of Set 6 | matthew town
# Processing Record 20 of Set 6 | kingston
# Processing Record 21 of Set 6 | felipe carrillo puerto
# Processing Record 22 of Set 6 | tayu
# Processing Record 23 of Set 6 | constantia
# Processing Record 24 of Set 6 | undurkhaan
# Processing Record 25 of Set 6 | port lincoln
# Processing Record 26 of Set 6 | abbeville
# Processing Record 27 of Set 6 | atbasar
# Processing Record 28 of Set 6 | ancud
# Processing Record 29 of Set 6 | ghanzi
# Processing Record 30 of Set 6 | uturoa
# Processing Record 31 of Set 6 | jericho
# Processing Record 32 of Set 6 | tegina
# Processing Record 33 of Set 6 | mangrol
# Processing Record 34 of Set 6 | wynyard
# Processing Record 35 of Set 6 | east ballina
# Processing Record 36 of Set 6 | talnakh
# Processing Record 37 of Set 6 | udachny
# Processing Record 38 of Set 6 | nadym
# Processing Record 39 of Set 6 | yermentau
# Processing Record 40 of Set 6 | labytnangi
# Processing Record 41 of Set 6 | san luis potosi
# Processing Record 42 of Set 6 | sos'va
# Processing Record 43 of Set 6 | huarmey
# Processing Record 44 of Set 6 | afaahiti
# Processing Record 45 of Set 6 | pirallahi
# Processing Record 46 of Set 6 | guaruja
# Processing Record 47 of Set 6 | pandan
# Processing Record 48 of Set 6 | alofi
# Processing Record 49 of Set 6 | sinabang
# Processing Record 0 of Set 7 | riosucio
# Processing Record 1 of Set 7 | langsa
# Processing Record 2 of Set 7 | tafuna
# Processing Record 3 of Set 7 | urangan
# Processing Record 4 of Set 7 | oruro
# Processing Record 5 of Set 7 | hadibu
# Processing Record 6 of Set 7 | namibe
# Processing Record 7 of Set 7 | vosendorf
# Processing Record 8 of Set 7 | northam
# Processing Record 9 of Set 7 | novo aripuana
# Processing Record 10 of Set 7 | arawa
# Processing Record 11 of Set 7 | punta alta
# Processing Record 12 of Set 7 | idri
# Processing Record 13 of Set 7 | gorontalo
# Processing Record 14 of Set 7 | harstad
# Processing Record 15 of Set 7 | mogilno
# Processing Record 16 of Set 7 | mawlaik
# Processing Record 17 of Set 7 | belel
# Processing Record 18 of Set 7 | ascencion de guarayos
# City not found. Skipping...
# Processing Record 19 of Set 7 | mount pleasant
# Processing Record 20 of Set 7 | chirilagua
# Processing Record 21 of Set 7 | howrah
# Processing Record 22 of Set 7 | chegdomyn
# Processing Record 23 of Set 7 | grand-bourg
# Processing Record 24 of Set 7 | daru
# Processing Record 25 of Set 7 | greymouth
# Processing Record 26 of Set 7 | nagqu
# Processing Record 27 of Set 7 | igarka
# Processing Record 28 of Set 7 | idfu
# Processing Record 29 of Set 7 | touros
# Processing Record 30 of Set 7 | grantsville
# Processing Record 31 of Set 7 | posto fiscal rolim de moura
# Processing Record 32 of Set 7 | taltal
# Processing Record 33 of Set 7 | awjilah
# Processing Record 34 of Set 7 | vernon
# Processing Record 35 of Set 7 | aksu
# Processing Record 36 of Set 7 | nabire
# Processing Record 37 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 38 of Set 7 | melekeok village
# Processing Record 39 of Set 7 | broome
# Processing Record 40 of Set 7 | faya-largeau
# Processing Record 41 of Set 7 | abu jibeha
# Processing Record 42 of Set 7 | san pedro
# Processing Record 43 of Set 7 | sharm el-sheikh
# Processing Record 44 of Set 7 | fort-shevchenko
# Processing Record 45 of Set 7 | ayutla
# Processing Record 46 of Set 7 | tanumah
# Processing Record 47 of Set 7 | sitka
# Processing Record 48 of Set 7 | remire-montjoly
# Processing Record 49 of Set 7 | kone
# Processing Record 0 of Set 8 | la passe
# Processing Record 1 of Set 8 | taksimo
# Processing Record 2 of Set 8 | paola
# Processing Record 3 of Set 8 | nova olinda do norte
# Processing Record 4 of Set 8 | fortuna
# Processing Record 5 of Set 8 | dwarka
# Processing Record 6 of Set 8 | port moresby
# Processing Record 7 of Set 8 | aykhal
# Processing Record 8 of Set 8 | rio grande
# Processing Record 9 of Set 8 | nieuw amsterdam
# Processing Record 10 of Set 8 | nantucket
# Processing Record 11 of Set 8 | kiunga
# Processing Record 12 of Set 8 | mount pearl
# Processing Record 13 of Set 8 | weno
# Processing Record 14 of Set 8 | san andres
# Processing Record 15 of Set 8 | shirgaon
# Processing Record 16 of Set 8 | luderitz
# Processing Record 17 of Set 8 | alegrete
# Processing Record 18 of Set 8 | rio rancho
# Processing Record 19 of Set 8 | axim
# Processing Record 20 of Set 8 | beira
# Processing Record 21 of Set 8 | gryazi
# Processing Record 22 of Set 8 | linxia chengguanzhen
# Processing Record 23 of Set 8 | winnemucca
# Processing Record 24 of Set 8 | broken hill
# Processing Record 25 of Set 8 | baiquan
# Processing Record 26 of Set 8 | sinop
# Processing Record 27 of Set 8 | caxito
# Processing Record 28 of Set 8 | semey
# Processing Record 29 of Set 8 | tatsinskiy
# Processing Record 30 of Set 8 | tutong
# Processing Record 31 of Set 8 | phan rang-thap cham
# Processing Record 32 of Set 8 | ugoofaaru
# Processing Record 33 of Set 8 | ivdel'
# Processing Record 34 of Set 8 | galle
# Processing Record 35 of Set 8 | samarinda
# Processing Record 36 of Set 8 | jackson
# Processing Record 37 of Set 8 | zalanga
# Processing Record 38 of Set 8 | tevragh zeina
# City not found. Skipping...
# Processing Record 39 of Set 8 | tubarjal
# Processing Record 40 of Set 8 | pokachi
# Processing Record 41 of Set 8 | esmeraldas
# Processing Record 42 of Set 8 | dong ha
# Processing Record 43 of Set 8 | nyakahanga
# Processing Record 44 of Set 8 | qulsary
# Processing Record 45 of Set 8 | yuzhno-kurilsk
# Processing Record 46 of Set 8 | horta
# Processing Record 47 of Set 8 | santa terezinha
# Processing Record 48 of Set 8 | seelow
# Processing Record 49 of Set 8 | reyes
# Processing Record 0 of Set 9 | cidreira
# Processing Record 1 of Set 9 | luebo
# Processing Record 2 of Set 9 | selfoss
# Processing Record 3 of Set 9 | cannonvale
# Processing Record 4 of Set 9 | ji'an
# Processing Record 5 of Set 9 | corinto
# Processing Record 6 of Set 9 | fort bragg
# Processing Record 7 of Set 9 | casino
# Processing Record 8 of Set 9 | gifford
# Processing Record 9 of Set 9 | svetlyy
# Processing Record 10 of Set 9 | rajgarh
# Processing Record 11 of Set 9 | qui nhon
# Processing Record 12 of Set 9 | greeley
# Processing Record 13 of Set 9 | mangalia
# Processing Record 14 of Set 9 | happy valley-goose bay
# Processing Record 15 of Set 9 | bamboo flat
# Processing Record 16 of Set 9 | puerto san jose
# Processing Record 17 of Set 9 | lake mohawk
# Processing Record 18 of Set 9 | abaete
# Processing Record 19 of Set 9 | elverum
# Processing Record 20 of Set 9 | bereznik
# Processing Record 21 of Set 9 | naze
# Processing Record 22 of Set 9 | mili
# Processing Record 23 of Set 9 | indore
# Processing Record 24 of Set 9 | mar del plata
# Processing Record 25 of Set 9 | guerrero negro
# Processing Record 26 of Set 9 | plettenberg bay
# Processing Record 27 of Set 9 | chom bueng
# Processing Record 28 of Set 9 | rovnoye
# Processing Record 29 of Set 9 | barra de santo antonio
# Processing Record 30 of Set 9 | pudasjarvi
# Processing Record 31 of Set 9 | waycross
# Processing Record 32 of Set 9 | de queen
# Processing Record 33 of Set 9 | morden
# Processing Record 34 of Set 9 | vandenberg village
# Processing Record 35 of Set 9 | menongue
# Processing Record 36 of Set 9 | porto novo
# Processing Record 37 of Set 9 | springbok
# Processing Record 38 of Set 9 | joroinen
# Processing Record 39 of Set 9 | monrovia
# Processing Record 40 of Set 9 | shalqar
# Processing Record 41 of Set 9 | usogorsk
# Processing Record 42 of Set 9 | nar'yan-mar
# Processing Record 43 of Set 9 | kapa'a
# Processing Record 44 of Set 9 | egilsstadir
# Processing Record 45 of Set 9 | ulladulla
# Processing Record 46 of Set 9 | lamu
# Processing Record 47 of Set 9 | san marcos yachihuacaltepec
# Processing Record 48 of Set 9 | santa cruz
# Processing Record 49 of Set 9 | watampone
# Processing Record 0 of Set 10 | el playon
# Processing Record 1 of Set 10 | kouango
# Processing Record 2 of Set 10 | toguchin
# Processing Record 3 of Set 10 | san nicolas
# Processing Record 4 of Set 10 | aswan
# Processing Record 5 of Set 10 | vi thanh
# City not found. Skipping...
# Processing Record 6 of Set 10 | kiiminki
# Processing Record 7 of Set 10 | tommot
# Processing Record 8 of Set 10 | harnosand
# Processing Record 9 of Set 10 | conceicao da barra
# Processing Record 10 of Set 10 | archangelos
# Processing Record 11 of Set 10 | taulaga
# Processing Record 12 of Set 10 | gannan
# Processing Record 13 of Set 10 | massaguet
# Processing Record 14 of Set 10 | bogandinskiy
# Processing Record 15 of Set 10 | sligo
# Processing Record 16 of Set 10 | shar'ya
# Processing Record 17 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 18 of Set 10 | mokhsogollokh
# Processing Record 19 of Set 10 | la quiaca
# Processing Record 20 of Set 10 | chibougamau
# Processing Record 21 of Set 10 | rosario del tala
# Processing Record 22 of Set 10 | al kharijah
# Processing Record 23 of Set 10 | edd
# Processing Record 24 of Set 10 | armacao de buzios
# Processing Record 25 of Set 10 | miandrivazo
# Processing Record 26 of Set 10 | bhawanipatna
# Processing Record 27 of Set 10 | brandon
# Processing Record 28 of Set 10 | keflavik
# Processing Record 29 of Set 10 | snyder
# Processing Record 30 of Set 10 | chagoda
# Processing Record 31 of Set 10 | cestos city
# Processing Record 32 of Set 10 | la'ie
# Processing Record 33 of Set 10 | port shepstone
# Processing Record 34 of Set 10 | alaghsas
# Processing Record 35 of Set 10 | milan
# Processing Record 36 of Set 10 | manistee
# Processing Record 37 of Set 10 | coxim
# Processing Record 38 of Set 10 | tual
# Processing Record 39 of Set 10 | matale
# Processing Record 40 of Set 10 | salem
# Processing Record 41 of Set 10 | navalmoral de la mata
# Processing Record 42 of Set 10 | srivardhan
# Processing Record 43 of Set 10 | mermoz boabab
# Processing Record 44 of Set 10 | benguela
# Processing Record 45 of Set 10 | butha-buthe
# Processing Record 46 of Set 10 | lazaro cardenas
# Processing Record 47 of Set 10 | yueyang
# Processing Record 48 of Set 10 | zaozersk
# Processing Record 49 of Set 10 | bishkul
# Processing Record 0 of Set 11 | brisas de zicatela
# Processing Record 1 of Set 11 | suoyarvi
# Processing Record 2 of Set 11 | mazagao
# Processing Record 3 of Set 11 | ha tien
# Processing Record 4 of Set 11 | san juan de uraba
# Processing Record 5 of Set 11 | sabang
# Processing Record 6 of Set 11 | eyl
# Processing Record 7 of Set 11 | moose jaw
# Processing Record 8 of Set 11 | nadi
# Processing Record 9 of Set 11 | chicxulub puerto
# City not found. Skipping...
# Processing Record 10 of Set 11 | baharly
# Processing Record 11 of Set 11 | cold lake
# Processing Record 12 of Set 11 | petrolina
# Processing Record 13 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 14 of Set 11 | najran
# Processing Record 15 of Set 11 | arkhangel'sk
# Processing Record 16 of Set 11 | tukrah
# Processing Record 17 of Set 11 | khanty-mansiysk
# Processing Record 18 of Set 11 | nanga eboko
# Processing Record 19 of Set 11 | penukonda
# Processing Record 20 of Set 11 | albertville
# Processing Record 21 of Set 11 | jianguang
# Processing Record 22 of Set 11 | puerto san carlos
# City not found. Skipping...
# Processing Record 23 of Set 11 | los angeles
# Processing Record 24 of Set 11 | hillvue
# Processing Record 25 of Set 11 | bozoum
# Processing Record 26 of Set 11 | suntar
# Processing Record 27 of Set 11 | praia da vitoria
# Processing Record 28 of Set 11 | amfissa
# Processing Record 29 of Set 11 | isla vista
# Processing Record 30 of Set 11 | callao
# Processing Record 31 of Set 11 | conception bay south
# Processing Record 32 of Set 11 | morococha
# Processing Record 33 of Set 11 | wuwei
# Processing Record 34 of Set 11 | signal mountain
# Processing Record 35 of Set 11 | passi
# Processing Record 36 of Set 11 | sao miguel do araguaia
# Processing Record 37 of Set 11 | geraldton
# Processing Record 38 of Set 11 | mana
# Processing Record 39 of Set 11 | mahina
# Processing Record 40 of Set 11 | bel ombre
# Processing Record 41 of Set 11 | westport
# Processing Record 42 of Set 11 | xinghua
# Processing Record 43 of Set 11 | hounde
# Processing Record 44 of Set 11 | saint-philippe
# Processing Record 45 of Set 11 | santa isabel
# Processing Record 46 of Set 11 | salida
# Processing Record 47 of Set 11 | jayapura
# Processing Record 48 of Set 11 | valledupar
# Processing Record 49 of Set 11 | amga
# Processing Record 0 of Set 12 | christchurch
# Processing Record 1 of Set 12 | walvis bay
# Processing Record 2 of Set 12 | kenai
# Processing Record 3 of Set 12 | grand-popo
# Processing Record 4 of Set 12 | turabah
# Processing Record 5 of Set 12 | pingliang
# Processing Record 6 of Set 12 | agat village
# Processing Record 7 of Set 12 | bambanglipuro
# Processing Record 8 of Set 12 | nalut
# Processing Record 9 of Set 12 | partenit
# Processing Record 10 of Set 12 | pacific grove
# Processing Record 11 of Set 12 | cambria
# Processing Record 12 of Set 12 | egersund
# Processing Record 13 of Set 12 | ranau
# Processing Record 14 of Set 12 | umba
# Processing Record 15 of Set 12 | naracoorte
# Processing Record 16 of Set 12 | kadoma
# Processing Record 17 of Set 12 | tbeng meanchey
# Processing Record 18 of Set 12 | cova figueira
# Processing Record 19 of Set 12 | ordynskoye
# Processing Record 20 of Set 12 | mumbwa
# Processing Record 21 of Set 12 | alesund
# Processing Record 22 of Set 12 | borogontsy
# Processing Record 23 of Set 12 | grand falls-windsor
# Processing Record 24 of Set 12 | morondava
# Processing Record 25 of Set 12 | karaton
# Processing Record 26 of Set 12 | belle chasse
# Processing Record 27 of Set 12 | al mazar al janubi
# Processing Record 28 of Set 12 | trzebiatow
# Processing Record 29 of Set 12 | sihanoukville
# Processing Record 30 of Set 12 | kapoeta
# Processing Record 31 of Set 12 | carolina beach
# Processing Record 32 of Set 12 | chernyshevskiy
# Processing Record 33 of Set 12 | el nido
# Processing Record 34 of Set 12 | bignona
# Processing Record 35 of Set 12 | majuro
# Processing Record 36 of Set 12 | ocean pines
# Processing Record 37 of Set 12 | port blair
# Processing Record 38 of Set 12 | huruta
# Processing Record 39 of Set 12 | kashin
# Processing Record 40 of Set 12 | salym
# Processing Record 41 of Set 12 | korla
# Processing Record 42 of Set 12 | massawa
# Processing Record 43 of Set 12 | slobozia
# Processing Record 44 of Set 12 | tshikapa
# Processing Record 45 of Set 12 | chiredzi
# Processing Record 46 of Set 12 | salmon arm
# Processing Record 47 of Set 12 | celestun
# Processing Record 48 of Set 12 | whakatane
# Processing Record 49 of Set 12 | sheridan
# Processing Record 0 of Set 13 | bandar-e lengeh
# Processing Record 1 of Set 13 | morehead city
# Processing Record 2 of Set 13 | okondja
# Processing Record 3 of Set 13 | maintirano
# Processing Record 4 of Set 13 | mahanoro
# Processing Record 5 of Set 13 | illizi
# Processing Record 6 of Set 13 | hammerfest
# Processing Record 7 of Set 13 | lensk
# Processing Record 8 of Set 13 | pacocha

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          590
# Lat           590
# Lng           590
# Max Temp      590
# Humidity      590
# Cloudiness    590
# Wind Speed    590
# Country       590
# Date          590
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 college  64.8569 -147.8028     53.55        86          75
# 1                waitangi -43.9535 -176.5597     54.82        80         100
# 2       port-aux-francais -49.3500   70.2167     33.60        60          99
# 3                hermanus -34.4187   19.2345     42.80        81          82
# 4  hawaiian paradise park  19.5933 -154.9731     81.03        81         100
#
#    Wind Speed Country        Date
# 0       12.66      US  1693884541
# 1        4.00      NZ  1693884541
# 2       25.23      TF  1693884541
# 3       12.53      ZA  1693884541
# 4        9.22      US  1693884542

# %%
# Export the City_Data into a csv
city_data_df.to_csv("..\output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("..\output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       college  64.8569 -147.8028     53.55        86
# 1                      waitangi -43.9535 -176.5597     54.82        80
# 2             port-aux-francais -49.3500   70.2167     33.60        60
# 3                      hermanus -34.4187   19.2345     42.80        81
# 4        hawaiian paradise park  19.5933 -154.9731     81.03        81
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75       12.66      US  1693884541
# 1               100        4.00      NZ  1693884541
# 2                99       25.23      TF  1693884541
# 3                82       12.53      ZA  1693884541
# 4               100        9.22      US  1693884542

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (Date)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.grid(True)

# Save the figure
plt.savefig("..\output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (Date)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("..\output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (Date)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("..\output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (Date)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("..\output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
from scipy.stats import linregress

def compute_linear_regression(x_values, y_values):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Return the linear regression parameters
    return slope, intercept, rvalue, pvalue, stderr

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       college  64.8569 -147.8028     53.55        86
# 4        hawaiian paradise park  19.5933 -154.9731     81.03        81
# 7                        taybad  34.7400   60.7756     70.30        28
# 9                kulhudhuffushi   6.6221   73.0700     81.95        76
# 11                  yellowknife  62.4560 -114.3525     46.92        61
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75       12.66      US  1693884541
# 4               100        9.22      US  1693884542
# 7                 0       10.45      IR  1693884542
# 9               100       14.32      MV  1693884543
# 11               75        4.61      CA  1693884337

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 waitangi -43.9535 -176.5597     54.82        80         100
# 2        port-aux-francais -49.3500   70.2167     33.60        60          99
# 3                 hermanus -34.4187   19.2345     42.80        81          82
# 5                papatowai -46.5619  169.4708     56.30        68          99
# 6                adamstown -25.0660 -130.1015     70.27        88          98
#
#          Wind Speed Country        Date
# City_ID
# 1              4.00      NZ  1693884541
# 2             25.23      TF  1693884541
# 3             12.53      ZA  1693884541
# 5              6.96      NZ  1693884542
# 6             15.86      PN  1693884542

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
def plot_linear_regression(x_values, y_values, title, x_label, y_label):
    # Compute linear regression
    slope, intercept, rvalue, pvalue, stderr = compute_linear_regression(x_values, y_values)

    # Calculate the regression line
    regress_values = x_values * slope + intercept

    # Create the scatter plot
    plt.scatter(x_values, y_values, marker="o", edgecolors="black", alpha=0.7)
    
    # Plot the regression line
    plt.plot(x_values, regress_values, "r-")

    # Annotate the equation on the plot
    plt.annotate(f"y = {round(slope, 2)}x + {round(intercept, 2)}", (min(x_values), min(y_values)), fontsize=12, color="red")

    # Set title and labels
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # Print the r-squared value
    print(f"The r-squared is: {rvalue**2}")

    # Show plot
    plt.show()

# Create a plot for Northern Hemisphere latitude vs. max temperature
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Northern Hemisphere - Latitude vs. Max Temperature", "Latitude", "Max Temperature (°F)")
# Out:
# The r-squared is: 0.6185084139618543

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Southern Hemisphere - Latitude vs. Max Temperature", "Latitude", "Max Temperature (°F)")
# Out:
# The r-squared is: 0.5105267745470784

# %% [markdown]
# **Discussion about the linear relationship:** As a trend, the lower the max temp, the lower the lattitude is. Locations closer to the south pole are colder.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Northern Hemisphere - Latitude vs. Humidity", "Latitude", "Humidity (%)")
# Out:
# The r-squared is: 0.002256942044638688

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Southern Hemisphere - Latitude vs. Humidity", "Latitude", "Humidity (%)")
# Out:
# The r-squared is: 0.0005090520384989214

# %% [markdown]
# **Discussion about the linear relationship:** Lattitude in the southern hemisphere seems to have little relationship with the relative humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Northern Hemisphere - Latitude vs. Cloudiness", "Latitude", "Cloudiness (%)")
# Out:
# The r-squared is: 0.0029271158717545835

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Southern Hemisphere - Latitude vs. Cloudiness", "Latitude", "Cloudiness (%)")
# Out:
# The r-squared is: 0.022591078182328066

# %% [markdown]
# **Discussion about the linear relationship:** There is very small negligible trend that the greater the lattitude from the equator, the cloudier it is. But the r value is soo small that it is not conclusive.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Northern Hemisphere - Latitude vs. Wind Speed", "Latitude", "Wind Speed (mph)")
# Out:
# The r-squared is: 0.009817623364750656

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Southern Hemisphere - Latitude vs. Wind Speed", "Latitude", "Wind Speed (mph)")
# Out:
# The r-squared is: 0.010749652927111641

# %% [markdown]
# **Discussion about the linear relationship:** There is no real relationship with lattitude in the southern hemisphere and the wind speed.
